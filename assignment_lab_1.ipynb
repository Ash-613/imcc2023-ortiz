# %% [markdown]
# <a href="https://colab.research.google.com/github/Ash-613/imcc2023-ortiz/blob/main/assignment_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display

# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# Cloning into 'imc2023'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (78/78), done.
# remote: Total 82 (delta 33), reused 14 (delta 1), pack-reused 0
# Unpacking objects: 100% (82/82), 5.83 MiB | 9.18 MiB/s, done.

# %%
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 44100
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
plt.plot(sig)

# %%
time=np.arange(0,sig.shape[0])/sr
plt.plot(time,sig)

# %%
excursion=max(abs(sig))
sigNew = sig / excursion
plt.plot(time,sigNew)

# %%
plt.plot(time,sigNew)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
def printText(string):
    print(string)

# %%
printText('Hello world!')
# Out:
# Hello world!

# %%
def printTextNum(string,number):
    print(string)
    print(number)

# %%
printTextNum('Hello world!',2)
# Out:
# Hello world!
# 2

# %%
printTextNum('avm.wav',44100)
# Out:
# avm.wav
# 44100

# %%
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 441
sig, sr = librosa.load(file,mono=True,sr=samplingRate)

# %%
plt.plot(sig)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
printTextNum(plt.plot(sigNew),44100)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# ...
# 44100
# Text(0, 0.5, 'Amplitude')

# %%
printTextNum(plt.plot(sig),441)
plt.xlabel('Time (seconds)')
plt.ylabel('Amplitude')
# Out:
# ...
# 441
# Text(0, 0.5, 'Amplitude')
